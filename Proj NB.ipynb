# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = pd.read_excel(r"C:\Users\Faiq Hilman\Documents\stroke.xlsx")
d
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
d = d.replace({'gender':{'Male':1, 'Female':2}})
print(d)
# Out:
#          id gender   age  hypertension  heart_disease ever_married  \
# 0      9046      1  67.0             0              1          Yes
# 1     51676      2  61.0             0              0          Yes
# 2     31112      1  80.0             0              1          Yes
# 3     60182      2  49.0             0              0          Yes
# 4      1665      2  79.0             1              0          Yes
# ...     ...    ...   ...           ...            ...          ...
# 5105  18234      2  80.0             1              0          Yes
# 5106  44873      2  81.0             0              0          Yes
# 5107  19723      2  35.0             0              0          Yes
# 5108  37544      1  51.0             0              0          Yes
# 5109  44679      2  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# ...

# %%
print(d.Residence_type.unique())
print(d.smoking_status.unique())
print(d.work_type.unique())
print(d.ever_married.unique())
# Out:
# ['Urban' 'Rural']
# ['formerly smoked' 'never smoked' 'smokes' 'Unknown']
# ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
# ['Yes' 'No']

# %%
d = d.replace({'Residence_type':{'Urban':1, 'Rural':2}})

# %%
d = d.replace({'smoking_status':{'formerly smoked':1, 'never smoked':2
                , 'smokes':3, 'Unknown':4}})
d
# Out:
#          id gender   age  hypertension  heart_disease ever_married  \
# 0      9046      1  67.0             0              1          Yes
# 1     51676      2  61.0             0              0          Yes
# 2     31112      1  80.0             0              1          Yes
# 3     60182      2  49.0             0              0          Yes
# 4      1665      2  79.0             1              0          Yes
# ...     ...    ...   ...           ...            ...          ...
# 5105  18234      2  80.0             1              0          Yes
# 5106  44873      2  81.0             0              0          Yes
# 5107  19723      2  35.0             0              0          Yes
# 5108  37544      1  51.0             0              0          Yes
# 5109  44679      2  44.0             0              0          Yes
#
#           work_type  Residence_type  avg_glucose_level   bmi  smoking_status  \
# 0           Private               1             228.69  36.6               1
# ...

# %%
d = d.replace({'work_type':{'Private':1, 'Self-employed':2
                , 'Govt_job':3, 'Children':4, 'Never_worked':5}})
d
# Out:
#          id gender   age  hypertension  heart_disease ever_married work_type  \
# 0      9046      1  67.0             0              1          Yes         1
# 1     51676      2  61.0             0              0          Yes         2
# 2     31112      1  80.0             0              1          Yes         1
# 3     60182      2  49.0             0              0          Yes         1
# 4      1665      2  79.0             1              0          Yes         2
# ...     ...    ...   ...           ...            ...          ...       ...
# 5105  18234      2  80.0             1              0          Yes         1
# 5106  44873      2  81.0             0              0          Yes         2
# 5107  19723      2  35.0             0              0          Yes         2
# 5108  37544      1  51.0             0              0          Yes         1
# 5109  44679      2  44.0             0              0          Yes         3
#
# ...

# %%
d = d.replace({'ever_married':{'Yes':1, 'No':2}})
d
# Out:
#          id gender   age  hypertension  heart_disease  ever_married work_type  \
# 0      9046      1  67.0             0              1             1         1
# 1     51676      2  61.0             0              0             1         2
# 2     31112      1  80.0             0              1             1         1
# 3     60182      2  49.0             0              0             1         1
# 4      1665      2  79.0             1              0             1         2
# ...     ...    ...   ...           ...            ...           ...       ...
# 5105  18234      2  80.0             1              0             1         1
# 5106  44873      2  81.0             0              0             1         2
# 5107  19723      2  35.0             0              0             1         2
# 5108  37544      1  51.0             0              0             1         1
# 5109  44679      2  44.0             0              0             1         3
#
# ...

# %%
d = d.replace({'stroke':{1:1, 0:2}})
d
# Out:
#          id gender   age  hypertension  heart_disease  ever_married work_type  \
# 0      9046      1  67.0             0              1             1         1
# 1     51676      2  61.0             0              0             1         2
# 2     31112      1  80.0             0              1             1         1
# 3     60182      2  49.0             0              0             1         1
# 4      1665      2  79.0             1              0             1         2
# ...     ...    ...   ...           ...            ...           ...       ...
# 5105  18234      2  80.0             1              0             1         1
# 5106  44873      2  81.0             0              0             1         2
# 5107  19723      2  35.0             0              0             1         2
# 5108  37544      1  51.0             0              0             1         1
# 5109  44679      2  44.0             0              0             1         3
#
# ...

# %%
d.describe()
# Out:
#                  id          age  hypertension  heart_disease  ever_married  \
# count   5110.000000  5110.000000   5110.000000    5110.000000   5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012      1.343836
# std    21161.721625    22.612647      0.296607       0.226063      0.475034
# min       67.000000     0.080000      0.000000       0.000000      1.000000
# 25%    17741.250000    25.000000      0.000000       0.000000      1.000000
# 50%    36932.000000    45.000000      0.000000       0.000000      1.000000
# 75%    54682.000000    61.000000      0.000000       0.000000      2.000000
# max    72940.000000    82.000000      1.000000       1.000000      2.000000
#
#        Residence_type  avg_glucose_level          bmi  smoking_status  \
# count     5110.000000        5110.000000  5110.000000     5110.000000
# mean         1.491977         106.147677    28.893237        2.585519
# std          0.499985          45.283560     7.698018        1.092522
# ...

# %%
print(d.isnull().sum())
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# pred                 0
# bmiOL                0
# glucoseOL            0
# dtype: int64

# %%
d['bmi'] = d['bmi'].fillna(d['bmi'].mean())

# %%
print(d.isnull().sum())
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# pred                 0
# bmiOL                0
# glucoseOL            0
# dtype: int64

# %%
d.describe()
# Out:
#                  id          age  hypertension  heart_disease  ever_married  \
# count   5110.000000  5110.000000   5110.000000    5110.000000   5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012      1.343836
# std    21161.721625    22.612647      0.296607       0.226063      0.475034
# min       67.000000     0.080000      0.000000       0.000000      1.000000
# 25%    17741.250000    25.000000      0.000000       0.000000      1.000000
# 50%    36932.000000    45.000000      0.000000       0.000000      1.000000
# 75%    54682.000000    61.000000      0.000000       0.000000      2.000000
# max    72940.000000    82.000000      1.000000       1.000000      2.000000
#
#        Residence_type  avg_glucose_level          bmi  smoking_status  \
# count     5110.000000        5110.000000  5110.000000     5110.000000
# mean         1.491977         106.147677    28.893237        2.585519
# std          0.499985          45.283560     7.698018        1.092522
# ...

# %%
sns.displot(d, x="bmi", color = 'purple', binwidth=1)
sns.displot(d, x="avg_glucose_level", color='purple',binwidth=3)

# %%
sns.displot(d, x="bmi", hue="gender", multiple="dodge")
sns.displot(d, x="avg_glucose_level", hue="gender", multiple="dodge")

# %%
sns.regplot(x=d["bmi"], y=d["avg_glucose_level"])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='avg_glucose_level'>

# %%
plt.plot( 'bmi', 'avg_glucose_level', data=d, linestyle='none', marker='o', alpha=0.3, color='purple')

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(d[['bmi']],d['avg_glucose_level'])
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: 77.46596260472371
# slope: [0.99267917]

# %%
r_sq=model.score(d[['bmi']],d['avg_glucose_level'])
print("R2=",r_sq)
# Out:
# R2= 0.02847701854061424

# %%
d['pred'] = model.predict(d[['avg_glucose_level']])

plt.scatter(d['avg_glucose_level'],d['bmi'],c="#77000022")
plt.scatter(d['avg_glucose_level'], d['pred'],c="#00770022")
# Out:
# C:\Users\Faiq Hilman\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - avg_glucose_level
# Feature names seen at fit time, yet now missing:
# - bmi
#
#   warnings.warn(message, FutureWarning)

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.boxplot(d['bmi'], 20)
ax1.set_title('bmi')
ax2.boxplot(d['avg_glucose_level'], 20)
ax2.set_title('Glucose')
plt.show()

# %%
d['bmiOL'] = 0 
d['glucoseOL'] = 0

# calculate the mean and standard deviations
meanbmi = d['bmi'].mean()
stdbmi = d['bmi'].std()
meangluc = d['avg_glucose_level'].mean()
stdgluc = d['avg_glucose_level'].std()

# %%
d.loc[abs(d['bmi'] - meanbmi) > 2 * stdbmi,'bmiOL'] = 1
d.loc[abs(d['avg_glucose_level'] - meangluc) > 2 * stdgluc,'glucoseOL'] = 1

from collections import Counter
print(Counter(d['bmiOL']))
print(Counter(d['glucoseOL']))
# Out:
# Counter({0: 4918, 1: 192})
# Counter({0: 4640, 1: 470})

# %%
colorColumn = []
for i in range(len(d)):
    if d["bmiOL"][i] == 1:
        colorColumn.append("#D06B36ff") # orange color
    elif d["glucoseOL"][i] == 1:
        colorColumn.append("#40A0C977") # a blueish color
    else:
        colorColumn.append("#B9BCC077") # gray

plt.xlabel('bmi')
plt.suptitle('bmi vs. glucose')
plt.ylabel('avg_glucose_level')
plt.scatter(d.bmi, d.avg_glucose_level , c = colorColumn, s = 50, linewidth= 0)

# %%
plt.plot( 'stroke', 'smoking_status', data=d, linestyle='none', marker='o', alpha=0.3, color='purple')

# %%
columnToTest = "avg_glucose_level"
column1 = "bmi"

# %%
import statsmodels.api as sm
#This contains theoretical distributions
from scipy import stats

#OPTION 1: statsmodel's qqplot. "fit" tells it to work out the parameters of the distribution
sm.qqplot(d[columnToTest], fit=True, line = 'r')
plt.show()

sm.qqplot(d[column1], dist=stats.norm, fit=True, line = 'r')
plt.show()

# %%
numeric_features = d.select_dtypes(include=[np.number])
corr = numeric_features.corr()
print (corr['stroke'].sort_values(ascending=False)[:15], '\n')
# Out:
# stroke               1.000000
# ever_married         0.108340
# smoking_status       0.066393
# Residence_type       0.015458
# bmiOL                0.006480
# id                  -0.006388
# bmi                 -0.038947
# glucoseOL           -0.122971
# hypertension        -0.127904
# avg_glucose_level   -0.131945
# pred                -0.131945
# heart_disease       -0.134914
# age                 -0.245257
# Name: stroke, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(d[['stroke']],d['age'])
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: 93.48484059256981
# slope: [-25.75664782]

# %%
r_sq=model.score(d[['stroke']],d['age'])
print("R2=",r_sq)
# Out:
# R2= 0.06015116585082947

# %%
d['pred'] = model.predict(d[['age']])

plt.scatter(d['age'],d['stroke'],c="#77000022")
plt.scatter(d['age'], d['pred'],c="#00770022")
# Out:
# C:\Users\Faiq Hilman\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - age
# Feature names seen at fit time, yet now missing:
# - stroke
#
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE

cols = ["gender","age","hypertension","heart_disease","ever_married","work_type","Residence_type","avg_glucose_level","bmi","gender"] 
X = d[cols]
y = d['stroke']
# Build a logreg and compute the feature importances
model = LogisticRegression()

# %%
Selected_features = ["gender","age","hypertension","heart_disease","ever_married","work_type","Residence_type","avg_glucose_level","bmi","gender"]
X = d[Selected_features]

plt.subplots(figsize=(8, 5))
sns.heatmap(X.corr(), annot=True, cmap="RdYlGn")
plt.show()

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score 
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_curve, auc, log_loss

# create X (features) and y (response)
X = d[Selected_features]
y = d['stroke']

# use train/test split with different random_state values
# we can change the random_state values that changes the accuracy scores
# the scores change a lot, this is why testing scores is a high-variance estimate
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# check classification scores of logistic regression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
y_pred_proba = logreg.predict_proba(X_test)[:, 1]
[fpr, tpr, thr] = roc_curve(y_test, y_pred_proba)
print('Train/Test split results:')
print(logreg.__class__.__name__+" accuracy is %2.3f" % accuracy_score(y_test, y_pred))
print(logreg.__class__.__name__+" log_loss is %2.3f" % log_loss(y_test, y_pred_proba))
print(logreg.__class__.__name__+" auc is %2.3f" % auc(fpr, tpr))

idx = np.min(np.where(tpr > 0.95)) # index of the first threshold for which the sensibility > 0.95

plt.figure()
plt.plot(fpr, tpr, color='coral', label='ROC curve (area = %0.3f)' % auc(fpr, tpr))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot([0,fpr[idx]], [tpr[idx],tpr[idx]], 'k--', color='blue')
plt.plot([fpr[idx],fpr[idx]], [0,tpr[idx]], 'k--', color='blue')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - specificity)', fontsize=14)
plt.ylabel('True Positive Rate (recall)', fontsize=14)
plt.title('Receiver operating characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()

print("Using a threshold of %.3f " % thr[idx] + "guarantees a sensitivity of %.3f " % tpr[idx] +  
      "and a specificity of %.3f" % (1-fpr[idx]) + 
      ", i.e. a false positive rate of %.2f%%." % (np.array(fpr[idx])*100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [84], in <cell line: 16>()
#      14 # check classification scores of logistic regression
#      15 logreg = LogisticRegression()
# ---> 16 logreg.fit(X_train, y_train)
#      17 y_pred = logreg.predict(X_test)
#      18 y_pred_proba = logreg.predict_proba(X_test)[:, 1]
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1508, in LogisticRegression.fit(self, X, y, sample_weight)
#    1505 else:
#    1506     _dtype = [np.float64, np.float32]
# -> 1508 X, y = self._validate_data(
#    1509     X,
#    1510     y,
#    1511     accept_sparse="csr",
#    1512     dtype=_dtype,
#    1513     order="C",
#    1514     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515 )
#    1516 check_classification_targets(y)
#    1517 self.classes_ = np.unique(y)
#
# ...
